# %% [markdown]
# ## Adding a Task to the End of a Circular To-Do List
#
# You are developing a task management system where tasks are stored in a circular to-do list.
# Each task is represented by a unique task ID. The circular nature of the list allows users to loop
# through their tasks continuously. Your task is to write a program that inserts a new task at the end
# of the circular linked list and prints the updated list of task IDs.Write a program to append a new
# task (represented by a unique task ID) to the end of the singly circular linked list representing the
# to-do list. After the insertion, print the updated list of task IDs by traversing the list once starting
# from the head.
#
# Input Format
# The first line contains an integer N, the number of initial tasks in the to-do list.
# The second line contains N space-separated integers representing the task IDs.
#
# Output Format
# Print the updated list of task IDs in sequence from the head of the list, traversing the circular list
# once.
#
# Constraints
# The input values are all positive integers.
# There will be at least one task initially in the to-do list.
#
# Sample Input
#
# 4
#
# 101 102 103 104
#
# Sample Output
#
# 101 102 103 104

# %%
def node(task_id):
    return {'task_id': task_id, 'next': None}

def insert_task(head, task_id):
    new_node = node(task_id)
    if head is None:
        new_node['next'] = new_node
        return new_node

    current = head
    while current['next'] != head:
        current = current['next']
    current['next'] = new_node
    new_node['next'] = head
    return head

def print_tasks(head):
    if head is None:
        return
    current = head
    while True:
        print(current['task_id'], end=' ')
        current = current['next']
        if current == head:
            break
    print()

# Read input
n = int(input())
task_ids = list(map(int, input().split()))
head = None
for task_id in task_ids:
    head = insert_task(head, task_id)

print_tasks(head)
# Out:
# 101 102 103 104

# %% [markdown]
# ## Sorting Books by Page Count
# A librarian needs to arrange books on a shelf in ascending order based on their page count. Each
# book has a unique page count, and the librarian wants to use the Bubble Sort algorithm to sort
# them efficiently.
#
# Given an unsorted list of book page counts, help the librarian sort the books in ascending order
# using Bubble Sort.
#
# Input Format
#     - An integer n representing the number of books.
#     - A list of n space-separated integers, where each integer represents the number of pages in a book.
#
# Output Format
#     - A single line of n space-separated integers representing the sorted page counts in ascending order.
#
# ### Example 1
#
# Sample Input 1
#
# 5
#
# 45 12 89 34 22
#
# Sample Output 1
#
# 12 22 34 45 89

# %%
def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(0, n-i-1):
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]
    return arr

number_of_elements = int(input())
elements = list(map(int, input().split()))
sorted_elements = bubble_sort(elements)
print("Sorted elements:", sorted_elements)
# Out:
# Sorted elements: [1, 2, 8, 9]

# %%
def insertion_sort(arr):
    for i in range(1, len(arr)):
        key = arr[i]
        j = i-1
        while j >=0 and key < arr[j]:
            arr[j + 1] = arr[j]
            j -= 1
        arr[j + 1] = key
    return arr

number_of_elements = int(input())
elements = list(map(int, input().split()))
sorted_elements = insertion_sort(elements)
print("Sorted elements:", sorted_elements)
# Out:
# Sorted elements: [60, 70, 80, 90]

# %%
def binary_search(arr, target):
    left, right = 0, len(arr) - 1
    while left <= right:
        mid = left + (right - left) // 2
        if arr[mid] == target:
            return mid
        elif arr[mid] < target:
            left = mid + 1
        else:
            right = mid - 1
    return -1

number_of_elements = int(input())
elements = list(map(int, input().split()))
target = int(input())
result = binary_search(elements, target)
if result != -1:
    # print(f"Element found at index {result}")
    print(result)
else:
    # print("Element not found in the array")
    print(-1)
# Out:
# 3
